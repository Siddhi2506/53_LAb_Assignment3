# %% [markdown]
# Course Name: Deep Learning
#
# Lab Title: YOLOv8 - Car Detection Application
#
# Students Name:
#
#  Siddhi Bambal 202201040127
#
#  Sai Gulve 202201040144
#
#  Dhanvantari Chavan 202201040143

# %% [markdown]
# # Task 1: Environment Setup

# %%
# Install necessary libraries
# !pip install ultralytics --quiet
import torch
from ultralytics import YOLO

# Set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# #Task 2: Dataset Preparation

# %%
# Mount Google Drive if dataset is on drive (optional)
#from google.colab import drive
#drive.mount('/content/drive')

# Upload and unzip dataset
from zipfile import ZipFile
import os

uploaded_path = '/content/3d_model_car.v1i.yolov8.zip'  # Update with your uploaded file path
extracted_path = '/content/3d_model_car'

# Unzip
with ZipFile(uploaded_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_path)

# Verify
os.listdir(extracted_path)
# Out:
# ['README.dataset.txt',
#  'test',
#  'valid',
#  'data.yaml',
#  'README.roboflow.txt',
#  'train']

# %% [markdown]
# # Task 3: Training YOLOv8 Model

# %%
# Load Pretrained YOLOv8 model
model = YOLO('yolov8n.pt')  # YOLOv8 nano version for faster training

# Train on your custom dataset
model.train(data='/content/3d_model_car/data.yaml', epochs=10, imgsz=640, device=device)
# Out:
# Ultralytics 8.3.118 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (AMD EPYC 7B12)
# ...

# %% [markdown]
# # Task 4: Inference and Evaluation

# %%
import os
for root, dirs, files in os.walk('/content/runs/detect'):
    for file in files:
        if file.endswith('.pt'):  # Look for files ending with .pt (model weights)
            print(os.path.join(root, file))
# Out:
# /content/runs/detect/train5/weights/last.pt
# /content/runs/detect/train5/weights/best.pt
# /content/runs/detect/train/weights/last.pt
# /content/runs/detect/train/weights/best.pt

# %%
# Validate model
metrics = model.val()

# Print basic metrics
print("\nValidation Results:")
print(f"mAP50-95: {metrics.box.map:.4f}")
print(f"Precision: {metrics.box.p}")  # Print the entire array
print(f"Recall: {metrics.box.r}")  # Print the entire array

# OR, to print the average precision/recall:

#print(f"Precision: {metrics.box.p.mean():.4f}")  # Print average precision
#print(f"Recall: {metrics.box.r.mean():.4f}")  # Print average recall


# F1 Score Calculation
# Modified to use metrics.box.p and metrics.box.r, using mean for overall score
f1_score = 2 * (metrics.box.p.mean() * metrics.box.r.mean()) / (metrics.box.p.mean() + metrics.box.r.mean() + 1e-6)
print(f"F1 Score: {f1_score:.4f}")

# Test predictions
results = model.predict(source='/content/3d_model_car/test/images', save=True)  # Or on any image
# Out:
# Ultralytics 8.3.118 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (AMD EPYC 7B12)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1307.9±315.1 MB/s, size: 23.7 KB)
# val: Scanning /content/3d_model_car/valid/labels.cache... 17 images, 0 backgrounds, 0 corrupt: 100%|██████████| 17/17 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
#                    all         17         63      0.871      0.794      0.939      0.845
#                    bus         10         10      0.827          1      0.978      0.894
#                  sedan          5          5      0.658          1      0.962      0.864
#                    suv          6          6          1      0.896      0.995      0.995
#                   tire         17         42          1      0.281       0.82      0.627
# Speed: 0.5ms preprocess, 89.1ms inference, 0.0ms loss, 1.2ms postprocess per image
# ...

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from ultralytics import YOLO

# Locate the Actual Model Path:
print(os.listdir('/content/runs/detect')) # List the contents of the 'detect' directory
print(os.listdir('/content/runs/detect/train2')) # List the contents of the weight directory if you have train54

# Load the trained model
model = YOLO('/content/runs/detect/train5/weights/best.pt')  # Update path to your best.pt

# Path to your test image
image_path = '/content/3d_model_car/test/images/_bus_30_s_50_24_jpg.rf.27faae1b5ce9641c8f844fc8fdb3a62e.jpg'  # Update with your test image

# Perform prediction
results = model.predict(source=image_path, save=False)  # save=False to not save to disk

# Get the first result (assuming you only have one image)
result = results[0]

# Load the image
img = mpimg.imread(image_path)

# Plot the image with bounding boxes
plt.figure(figsize=(10, 10))
plt.imshow(img)
ax = plt.gca()

# Plot bounding boxes and labels
for *xyxy, conf, cls in result.boxes.data:
    x1, y1, x2, y2 = map(int, xyxy)
    label = f'{model.names[int(cls)]} {conf:.2f}'
    ax.add_patch(plt.Rectangle((x1, y1), x2 - x1, y2 - y1, fill=False, color='red', linewidth=2))
    ax.text(x1, y1, label, color='white', fontsize=12, bbox=dict(facecolor='red', alpha=0.5))

plt.axis('off')
plt.title('Car Detection Results')
plt.show()
# Out:
# ['train2', 'train52', 'train54', 'train53', 'train55', 'train56', 'train5', 'train', 'train4', 'train3']
# ['val_batch2_pred.jpg', 'val_batch0_labels.jpg', 'R_curve.png', 'val_batch1_pred.jpg', 'val_batch1_labels.jpg', 'confusion_matrix_normalized.png', 'confusion_matrix.png', 'PR_curve.png', 'P_curve.png', 'val_batch0_pred.jpg', 'val_batch2_labels.jpg', 'F1_curve.png']
#
# image 1/1 /content/3d_model_car/test/images/_bus_30_s_50_24_jpg.rf.27faae1b5ce9641c8f844fc8fdb3a62e.jpg: 320x640 1 bus, 84.5ms
# Speed: 1.6ms preprocess, 84.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)

# %% [markdown]
# ## Discussion:
# - mAP50-95 achieved: [write your value]
# - Precision and Recall were [write values].
# - F1 Score balanced between Precision and Recall.
# - Overall model performed [good/average/bad] based on limited dataset size.
# - Potential Improvements: More epochs, data augmentation, larger dataset.
#
# ## Conclusion:
# This lab helped us understand YOLOv8 model training and evaluation on a custom Car Detection dataset. Results showed that even with a small dataset, decent detection accuracy can be achieved.

# %% [markdown]
# I, Siddhi Bambal, confirm that the work submitted in this assignment is my own and has been completed following academic integrity guidelines.
#
# GitHub Repository Link: [Your GitHub link]
#
# Signature: Siddhi Ishwar Bambal
